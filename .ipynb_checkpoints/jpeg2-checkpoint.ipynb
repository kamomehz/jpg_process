# %%
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
# from math import sqrt, pi, exp
# import cv2
# import JPEGFUNC
from JPEGFUNC import *

# %%
ycc
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-7b6235a4e719> in <module>
# ----> 1 ycc
#
# NameError: name 'ycc' is not defined

# %%
ori=Image.open("Saika.png")
arrayOri=np.array(ori)
cbcr=ycc(arrayOri[:,:,:3])

fig=plt.figure(figsize=(20,10))
ax = fig.subplots(2, 2)

ax[0,0].imshow(arrayOri)
ax[0,1].imshow(cbcr[:,:,0],"gray")
ax[1,0].imshow(cbcr[:,:,1],"gray")
ax[1,1].imshow(cbcr[:,:,2],"gray")
# ax[1,1].imshow(_rgb(cbcr[:,:,2]),cmap="gray")

ax[0,0].set_title("RGB")
ax[0,1].set_title("Y")
ax[1,0].set_title("Cb")
ax[1,1].set_title("Cr")

plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-4222f8fa9839> in <module>
#       1 ori=Image.open("Saika.png")
#       2 arrayOri=np.array(ori)
# ----> 3 cbcr=ycc(arrayOri[:,:,:3])
#       4
#       5 fig=plt.figure(figsize=(20,10))
#
# NameError: name 'ycc' is not defined

# %%
fig1=cutTo8(cbcr)
fig1[:,:,0].shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-10af61ee856f> in <module>
# ----> 1 fig1=cutTo8(cbcr)
#       2 fig1[:,:,0].shape
#
# NameError: name 'cbcr' is not defined

# %%
def test(x):
    return x*10

a,b,c=map(test,[1,2,3])

# %%
Gy,Gcb,Gcr=map(dct02,(fig1[:,:,0],fig1[:,:,1],fig1[:,:,2]))

By=Qy(Gy)
Bcb=Qc(Gcb)
Bcr=Qc(Gcr)
Bs=np.stack([By.reshape(-1),Bcb.reshape(-1),Bcr.reshape(-1)],-1)

# %%
iGy=iQy(By)
iGcb,iGcr= iQc(Bcb),iQc(Bcr)

# %%
N=128
x = np.arange(N)
y2 = np.sin(6*x/N*np.pi)+np.random.randn(N)*0.3#np.cos(x)-np.sin(3*x)
    
plt.plot(y2)
plt.show()

# %%
# plt.plot(np.abs(dft(y2)))
# plt.plot(idft(y2))
# plt.plot(dct0(y2))
# plt.plot(dct0_dft(y2))
plt.plot(fct(y2))
# plt.plot(idct0(dct0(y2)))
# plt.plot(dct0_fft(dct0_fft(y2)))
plt.plot(dct(y2,axis=0, norm='ortho' ))
# plt.plot(y2)
# plt.plot(np.abs(fft(y2)))
# plt.plot(ifft((fft(y2))))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-d6c91d659b88> in <module>
#       3 # plt.plot(dct0(y2))
#       4 # plt.plot(dct0_dft(y2))
# ----> 5 plt.plot(fct(y2))
#       6 # plt.plot(idct0(dct0(y2)))
#       7 # plt.plot(dct0_fft(dct0_fft(y2)))
#
# NameError: name 'fct' is not defined

# %%
plt.imshow(fig1[:,:,0], 'gray')

# %%
from scipy.fftpack import dct, idct

# set_printoptions(linewidth=200, precision=1, suppress=True)

def dct2(a):
    return dct( dct( a, axis=0, norm='ortho' ), axis=1, norm='ortho' )

def idct2(a):
    return idct( idct( a, axis=0 , norm='ortho'), axis=1 , norm='ortho')

# %%
Zs=Bs[Zigzag(8)]

# %%
# log_shift_dct_img=np.log(1+np.abs(dct2(fig1[:,:,0])))
# dct_img=np.log(1+np.abs(dct2(fig1[:,:,0])))
# plt.imshow(dct_img, 'gray')
Gy=
plt.imshow(dct2(fig1[:,:,0]).real, 'gray')
# plt.imshow(np.abs(dct2(cbcr[:512,:512,0])[:10,:10]), 'gray')
