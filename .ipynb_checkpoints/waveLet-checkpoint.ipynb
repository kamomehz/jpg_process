# %%
from PIL import Image
import numpy as np
from matplotlib import pyplot as plt
from math import sqrt, pi, exp
import cv2

# %%
ori=Image.open("Saika.png")
arrayOri=np.array(ori)
def show(pic):
    plt.figure(figsize=(20,10))
    plt.imshow(pic,cmap="gray")
#     plt.gray()
#     plt.imshow(pic)

# %%
show(arrayOri)

# %%
def grayG(x):
    r=x[:,:,0].reshape(-1)
    g=x[:,:,1].reshape(-1)
    b=x[:,:,2].reshape(-1)
    g=((r**2.2+(1.5*g)**2.2+(0.6*b)**2.2)/(1+1.5**2.2+0.6**2.2))**(1/2.2)
    return g.reshape(x.shape[:2])

def grayL(x):
    r=x[:,:,0].reshape(-1)
    g=x[:,:,1].reshape(-1)
    b=x[:,:,2].reshape(-1)
    g=r*0.3+g*0.59+b*0.11
    return g.reshape(x.shape[:2])

# %%
# grayGamma=grayG(arrayOri)
# show(grayGamma)
grayLinear=grayL(arrayOri)
show(grayLinear)

# %%
N = 128            # サンプル数
s = N/256           # 標準偏差

x = np.arange(N)
y2 = np.sin(6*x/N*np.pi)+np.random.randn(N)*0.3#np.cos(x)-np.sin(3*x)
    
plt.plot(y2)
# plt.xlim([N/2-100,N/2+100])
plt.show()

# %%
def fft(x):
    n=x.size
    if n == 2:
        return [x[0]+x[1],x[0]-x[1]]
    
    x1 = fft(x[::2])
    x2 = fft(x[1::2])
    W = np.exp(-2j*np.pi*np.arange(n//2)/n)
    W_x2= W*x2
    X = np.concatenate([x1+W_x2, x1-W_x2])
    return X

# %%
plt.plot(np.abs(fft0(y2)))
# plt.plot(np.abs(np.fft.fft(y2)))

# %%
def normalize(img):
    vmin = np.min(img)
    vmax = np.max(img)
    return (img - vmin) / (vmax - vmin) * 255

def fft(x):
    n=x.size
    if n == 2:
        return [x[0]+x[1],x[0]-x[1]]
    
    x1 = fft(x[::2])
    x2 = fft(x[1::2])
    W = np.exp(-2j*np.pi*np.arange(n//2)/n)
    W_x2= W*x2
    X = np.concatenate([x1+W_x2, x1-W_x2])
    return X

def fft2(img):
    h, w = img.shape
    if ((h-1) & h) or ((w-1) & w):
        print('Image size not a power of 2')
        return img
    
    img = normalize(img)
    res = np.zeros([h, w], 'complex128')
    for i in range(h):
        res[i, :] = fft(img[i, :])
    for j in range(w):
        res[:, j] = fft(res[:, j])
    return res

def fftshift(img):
    # swap the first and third quadrants, and the second and fourth quadrants
    h, w = img.shape
    h_mid, w_mid = h//2, w//2
    res = np.zeros([h, w], 'complex128')
    res[:h_mid, :w_mid] = img[h_mid:, w_mid:]
    res[:h_mid, w_mid:] = img[h_mid:, :w_mid]
    res[h_mid:, :w_mid] = img[:h_mid, w_mid:]
    res[h_mid:, w_mid:] = img[:h_mid, :w_mid]
    return res

# %%
grayResize=grayLinear[200:200+512,600:600+512]

# %%
fft_img = fft2(grayResize)
shift_fft_img = np.abs(fftshift(fft_img))
log_shift_fft_img = np.log(1 + shift_fft_img)

# %%
plt.imshow(log_shift_fft_img, 'gray'),
# Out:
# (<matplotlib.image.AxesImage at 0x7fc0798a09d0>,)

# %%
plt.imshow(log_shift_fft_img, 'gray'),
# Out:
# (<matplotlib.image.AxesImage at 0x7fc07993bd50>,)

# %%
plt.imshow(grayResize, 'gray')
